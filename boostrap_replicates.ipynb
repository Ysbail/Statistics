# %%
import numpy as np
import pickle as pkl
from stat_func import draw_bs_reps
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
with open('nohitter_times.pkl', 'rb') as f:
    nohitter_times = pkl.load(f)

# %%
bs_replicates = draw_bs_reps(nohitter_times, np.mean, 10000)

# %%
conf_int = np.percentile(bs_replicates, [2.5, 97.5])

# %%
print('95% confidence interval =', conf_int, 'games')
# Out:
# 95% confidence interval = [662.41035857 871.2438247 ] games

# %%
plt.hist(bs_replicates, bins=50, density=True)
plt.xlabel(r'$\tau$ (games)')
plt.ylabel('PDF')
plt.show()
